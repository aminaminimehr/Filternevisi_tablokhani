# %%
import numpy as np
import pandas as pd
import requests as re
import time
import datetime

# %%
df = pd.read_excel('Data saham.xlsx')

address_sahm = pd.read_excel('Ticker data.xlsx')


def call_webpage(index , industry_id):
    request = re.get(f'http://www.tsetmc.com/tsev2/data/instinfodata.aspx?i={index}&c={industry_id}')
    request = request.text
    return request

# %%
df = pd.read_excel('Data saham.xlsx')
for m in range (0,2):
    for i in range(0 , 50): #len(address_sahm)

        index = str(address_sahm['Index'].iloc[i])
        ind_id = str(address_sahm['Industry ID'].iloc[i])

        data_sahm = call_webpage(index , ind_id)

        if data_sahm != '':

            data_sahm = data_sahm.split(';')

            khate_aval = data_sahm[0].split(',')

            if khate_aval[1] =='A ':
                if i == 0:
                    df = df.append( {address_sahm['Ticker name'].iloc[i] + ' زمان' : khate_aval[0]} , ignore_index = True )
                else:
                    df[address_sahm['Ticker name'].iloc[i] + ' زمان'].loc[len(df) - 1] = khate_aval[0]

                df[address_sahm['Ticker name'].iloc[i] + ' آخرین معامله'].loc[len(df) - 1] = khate_aval[2]
                df[address_sahm['Ticker name'].iloc[i] + ' قیمت پایانی'].loc[len(df) - 1] = khate_aval[3]

                if data_sahm[4] != '' :
                    khate_panjom = data_sahm[4].split(',')

                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقیقی'].loc[len(df) - 1] = khate_panjom[5]
                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقوقی'].loc[len(df) - 1] = khate_panjom[6]
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم خرید حقیقی'].loc[len(df) - 1] = khate_panjom[0]
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم خرید حقوقی'].loc[len(df) - 1] = khate_panjom[1]
                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد فروش حقیقی'].loc[len(df) - 1] = khate_panjom[8]
                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد فروش حقوقی'].loc[len(df) - 1] = khate_panjom[9]
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم فروش حقیقی'].loc[len(df) - 1] = khate_panjom[3]
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم فروش حقوقی'].loc[len(df) - 1] = khate_panjom[4]
                else:

                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقیقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقوقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم خرید حقیقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم خرید حقوقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد فروش حقیقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' تعداد فروش حقوقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم فروش حقیقی'].loc[len(df) - 1] = 'NA'
                    df[address_sahm['Ticker name'].iloc[i] + ' حجم فروش حقوقی'].loc[len(df) - 1] = 'NA'

            else:
                if i == 0:
                    df = df.append( {address_sahm['Ticker name'].iloc[i] + ' زمان' : khate_aval[0]} , ignore_index = True )
                else:
                    df[address_sahm['Ticker name'].iloc[i] + ' زمان'].loc[len(df) - 1] = khate_aval[0]

                df[address_sahm['Ticker name'].iloc[i] + ' آخرین معامله'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' قیمت پایانی'].loc[len(df) - 1] = '-'



                df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقیقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقوقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' حجم خرید حقیقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' حجم خرید حقوقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' تعداد فروش حقیقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' تعداد فروش حقوقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' حجم فروش حقیقی'].loc[len(df) - 1] = '-'
                df[address_sahm['Ticker name'].iloc[i] + ' حجم فروش حقوقی'].loc[len(df) - 1] = '-'

        print(address_sahm['Ticker name'].iloc[i]  + '     =================> Done')
        if len(df) > 1:
            if df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقوقی'].iloc[len(df) - 1] > df[address_sahm['Ticker name'].iloc[i] + ' تعداد خرید حقوقی'].iloc[len(df) - 2]:
                print("kharidar hoghughi vared shod")
